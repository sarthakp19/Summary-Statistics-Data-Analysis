# %% [markdown]
# # Exploring Mushrooms
#
# Mushrooms exist in a variety of different colors, shapes, sizes, textures, etc. In this project, we will analyze an extensive mushroom dataset from UCI using bar charts and acquaint ourself with the diverse array of mushrooms that exist worldwide.

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('mushroom_data.csv') 
print(df.columns)
df.head()
# Out:
# Index(['Class', 'Cap Shape', 'Cap Surface', 'Cap Color', 'Bruises', 'Odor',
#        'Gill Attachment', 'Gill Spacing', 'Gill Size', 'Gill Color',
#        'Stalk Shape', 'Stalk Root', 'Stalk Surface Above Ring',
#        'Stalk Surface Below Ring', 'Stalk Color Above Ring',
#        'Stalk Color Below Ring', 'Veil Type', 'Veil Color', 'Ring Number',
#        'Ring Type', 'Spore Print Color', 'Population', 'Habitat'],
#       dtype='object')
#        Class Cap Shape Cap Surface Cap Color  Bruises     Odor  \
# 0  Poisonous    Convex      Smooth     Brown     True  Pungent
# 1     Edible    Convex      Smooth    Yellow     True   Almond
# 2     Edible      Bell      Smooth     White     True    Anise
# 3  Poisonous    Convex       Scaly     White     True  Pungent
# 4     Edible    Convex      Smooth      Gray    False     None
#
#   Gill Attachment Gill Spacing Gill Size Gill Color  ...  \
# 0            Free        Close    Narrow      Black  ...
# ...

# %%
for column in df.columns:
    plt.figure(figsize=(10,8))
    sns.countplot(df[column],order=df[column].value_counts().index)
    plt.title(f'Countplot For {column}')
    plt.show()
    plt.clf()
# Out:
# C:\Users\vaibh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vaibh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\vaibh\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# # Now that they are titled, labeled clearly, and ordered, we can really dive in on our analysis.
#
# Think about how someone could best use these visualizations. It is easy to tell which features of mushrooms are common and rare, and we get insights into the variety of mushrooms in the fungi kingdom.
#
# After Spending some time looking over the graphs. we find some exciting insights . Here are some examples:
#
# 1] It is a roughly equal split between mushrooms that are edible vs. poisonous.
#
#
# 2] The majority of mushrooms in this dataset have a scaly surface.
#
#
# 3] There are a non-insignificant amount of mushrooms that give off an almond scent?!!!
#
#
# 4] Most top surfaces of mushrooms in this dataset are scaly rather than smooth.
#
#
# Some of your analysis may also require research into mushroom features for any of the x-labels.
